# %% [markdown]
# <a href="https://colab.research.google.com/github/jisusP/Articulo/blob/main/TARIS_dendrograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt


url = "https://raw.githubusercontent.com/jisusP/Articulo/main/similarity2.csv"
df = pd.read_csv(url, header=None)

# Preprocesa los datos si es necesario
df = df.drop(df.columns[0], axis=1)
matrix = df.values
lab = ["1 (62)","2 (>250)","3 (>250)","4 (62)","5 (125)","6 (>250)","7 (>250)","8 (125)","9 (250)","10 (>250)","11 (62)","12 (125)"]

df
# Out:
#             1           2           3           4           5           6   \
# 0   100.000000   67.893004   68.186979   50.670450   61.249034   55.379562
# 1    67.893004  100.000000   88.159541   59.233105   39.901432   82.808065
# 2    68.186979   88.159541  100.000000   66.826426   48.697687   83.044184
# 3    50.670450   59.233105   66.826426  100.000000   80.668327   71.679428
# 4    61.249034   39.901432   48.697687   80.668327  100.000000   53.550689
# 5    55.379562   82.808065   83.044184   71.679428   53.550689  100.000000
# 6    53.694378   28.321807   37.354851   58.909307   71.149665   43.596915
# 7    28.996568   14.643335   22.465910    6.333637   12.374213    8.427192
# 8    75.542267   54.730649   62.556933   64.606823   72.250306   66.704088
# 9    68.340772   90.170867   96.772939   68.134288   48.802615   81.696588
# 10   63.035863   49.507990   55.267628   84.613521   89.206058   60.120630
# ...

# %%
matrix_d = 100 - matrix
plt.figure(figsize=(18,5))
plt.title("Cándida Albicans (TARIS)")
d = shc.dendrogram(shc.linkage(matrix_d, method = "ward"), labels = lab)
# Out:
# <ipython-input-7-568fb89af94f>:4: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   d = shc.dendrogram(shc.linkage(matrix_d, method = "ward"), labels = lab)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np



# Crear el heatmap sin mostrar los números
plt.figure(figsize=(10, 8))
sns.heatmap(matrix_d, annot=False, cbar=True, square=True, cmap='viridis')
plt.xticks(np.arange(len(lab)) + 0.5, lab, rotation=45, ha='right')
plt.yticks(np.arange(len(lab)) + 0.5, lab, rotation=45, ha='right')
# Configurar el aspecto del heatmap
plt.title("Mapa de calor (TARIS)")
plt.xlabel
plt.ylabel

# Mostrar el heatmap
plt.show()
