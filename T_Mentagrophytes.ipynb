# %% [markdown]
# <a href="https://colab.research.google.com/github/jisusP/Articulo/blob/main/T_Mentagrophytes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit 
# !pip install sklearn
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.metrics.pairwise import cosine_similarity
import plotly.figure_factory as ff
from rdkit import Chem
from rdkit import DataStructs
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial.distance import pdist, squareform

smiles = [
    "CCC1=CC=C2N=C(C=CC2=C1)C1=NC=CC=C1",
    "ClC1=CC=C2N=C(C=CC2=C1)C1=CN=CC=C1",
    "FC1=CC=C2N=C(C=CC2=C1)C1=CN=CC=C1",
    "C1=CC=C2N=C(C=CC2=C1)C1=CC=NC=C1",
    "CC1=CC=C2N=C(C=CC2=C1)C1=CC=NC=C1",
    "ClC1=CC=C2N=C(C=CC2=C1)C1=CC=NC=C1",
    "ClC1=C2N=C(C=CC2=CC=C1)C1=CC=NC=C1",
    "FC1=CC=C2N=C(\\C=C\\C3=NC=CC=C3)C=CC2=C1",
    "C(=C/C1=NC2=CC=CC=C2C=C1)\\C1=CN=CC=C1",
    "ClC1=CC=C2N=C(\\C=C\\C3=CN=CC=C3)C=CC2=C1",
    "C(=C/C1=NC2=CC=CC=C2C=C1)\\C1=CC=NC=C1",
    "ClC1=CC=C2N=C(\C=C\C3=CC=NC=C3)C=CC2=C1 "
]
mols = [Chem.MolFromSmiles(smile) for smile in smiles]
fps = [AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024) for mol in mols]
similarity_matrix_cos = cosine_similarity(fps)
distance_matrix_euc = squareform(pdist(fps, 'euclidean'))
similarity_matrix_euc = 1 / (1 + distance_matrix_euc)
similarity_matrix_tani = np.zeros((len(fps), len(fps)))
for i in range(len(fps)):
    for j in range(i+1, len(fps)):
        similarity = DataStructs.TanimotoSimilarity(fps[i], fps[j])
        similarity_matrix_tani[i][j] = similarity
        similarity_matrix_tani[j][i] = similarity 
distance_tani = 1-(similarity_matrix_tani)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rdkit
#   Downloading rdkit-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.22.4)
# Installing collected packages: rdkit
# Successfully installed rdkit-2022.9.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn
#   Downloading sklearn-0.0.post4.tar.gz (3.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# # **Coeficiente coseno **

# %%
#Matriz 1_ 
distance_matrix_cos = 1 - similarity_matrix_cos
lab = ["6 (62/62)","7 (31/125)","8 (62/62)","9 (62/62)","10 (62/62)","11 (125/125)","12 (62/125)","13 (125/>250)","14 (62/250)","15 (250/>250)","16 (31/125)","17 (62/125)"]
fig = ff.create_dendrogram(distance_matrix_cos, labels= lab)
fig.update_layout(width=800, height=500, title = "T_Mentagrophytes (C. coseno 1)", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6e5c620a-575a-4476-9f26-5e4f60e01be4" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e5c620a-575a-4476-9f26-5e4f60e01be4")) {                    Plotly.newPlot(                        "6e5c620a-575a-4476-9f26-5e4f60e01be4",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[15.0,15.0,25.0,25.0],"xaxis":"x","y":[0.0,0.4198083722285977,0.4198083722285977,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[35.0,35.0,45.0,45.0],"xaxis":"x","y":[0.0,0.4332672495668192,0.4332672495668192,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[20.0,20.0,40.0,40.0],"xaxis":"x","y":[0.4198083722285977,0.7311766378615137,0.7311766378615137,0.4332672495668192],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[5.0,5.0,30.0,30.0],"xaxis":"x","y":[0.0,0.7930168649202077,0.7930168649202077,0.7311766378615137],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[65.0,65.0,75.0,75.0],"xaxis":"x","y":[0.0,0.6153986436565354,0.6153986436565354,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[85.0,85.0,95.0,95.0],"xaxis":"x","y":[0.0,0.4627378042803549,0.4627378042803549,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[105.0,105.0,115.0,115.0],"xaxis":"x","y":[0.0,0.4653147935998349,0.4653147935998349,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[90.0,90.0,110.0,110.0],"xaxis":"x","y":[0.4627378042803549,0.747232002928906,0.747232002928906,0.4653147935998349],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[70.0,70.0,100.0,100.0],"xaxis":"x","y":[0.6153986436565354,0.9223161179818405,0.9223161179818405,0.747232002928906],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[55.0,55.0,85.0,85.0],"xaxis":"x","y":[0.0,1.010895931413695,1.010895931413695,0.9223161179818405],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[17.5,17.5,70.0,70.0],"xaxis":"x","y":[0.7930168649202077,1.2545754769433544,1.2545754769433544,1.010895931413695],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":500,"hovermode":"closest","showlegend":false,"width":800,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["13 (125/>250)","15 (250/>250)","17 (62/125)","14 (62/250)","16 (31/125)","6 (62/62)","9 (62/62)","12 (62/125)","10 (62/62)","11 (125/125)","7 (31/125)","8 (62/62)"],"tickvals":[5.0,15.0,25.0,35.0,45.0,55.0,65.0,75.0,85.0,95.0,105.0,115.0],"type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d ...

# %%
#Matriz 2
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
plt.figure(figsize=(18,5))
plt.title("T_Mentagrophytes (C. coseno 2)")
d = shc.dendrogram(shc.linkage(distance_matrix_cos, method = "ward"), labels = lab)

# %% [markdown]
# # **Distancia Euclidiana**

# %%
#Matriz 1
fig = ff.create_dendrogram(distance_matrix_euc, labels= lab)
fig.update_layout(width=800, height=500,  title = " T_Mentagrophytes (D. euclidiana 1)", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="eaab0f38-8b46-4600-ad8c-f1ef2e760739" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eaab0f38-8b46-4600-ad8c-f1ef2e760739")) {                    Plotly.newPlot(                        "eaab0f38-8b46-4600-ad8c-f1ef2e760739",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[15.0,15.0,25.0,25.0],"xaxis":"x","y":[0.0,5.231210152296332,5.231210152296332,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[35.0,35.0,45.0,45.0],"xaxis":"x","y":[0.0,5.448877531826406,5.448877531826406,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[20.0,20.0,40.0,40.0],"xaxis":"x","y":[5.231210152296332,7.515109623969724,7.515109623969724,5.448877531826406],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[5.0,5.0,30.0,30.0],"xaxis":"x","y":[0.0,8.146057295975309,8.146057295975309,7.515109623969724],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[65.0,65.0,75.0,75.0],"xaxis":"x","y":[0.0,5.464983493841029,5.464983493841029,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[105.0,105.0,115.0,115.0],"xaxis":"x","y":[0.0,5.379110352221716,5.379110352221716,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[95.0,95.0,110.0,110.0],"xaxis":"x","y":[0.0,6.091549866866844,6.091549866866844,5.379110352221716],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[85.0,85.0,102.5,102.5],"xaxis":"x","y":[0.0,7.221898775450544,7.221898775450544,6.091549866866844],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[70.0,70.0,93.75,93.75],"xaxis":"x","y":[5.464983493841029,8.50548727963804,8.50548727963804,7.221898775450544],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[55.0,55.0,81.875,81.875],"xaxis":"x","y":[0.0,9.20272181803278,9.20272181803278,8.50548727963804],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[17.5,17.5,68.4375,68.4375],"xaxis":"x","y":[8.146057295975309,10.35117721700571,10.35117721700571,9.20272181803278],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":500,"hovermode":"closest","showlegend":false,"width":800,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["13 (125/>250)","14 (62/250)","16 (31/125)","15 (250/>250)","17 (62/125)","6 (62/62)","7 (31/125)","8 (62/62)","12 (62/125)","9 (62/62)","10 (62/62)","11 (125/125)"],"tickvals":[5.0,15.0,25.0,35.0,45.0,55.0,65.0,75.0,85.0,95.0,105.0,115.0],"type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d", ...

# %%
#Matriz 2
plt.figure(figsize=(20,5))
plt.title(" T_Mentagrophytes (D. euclidiana 2)")
d = shc.dendrogram(shc.linkage(distance_matrix_euc, method = "ward"), labels = lab)
# Out:
# <ipython-input-8-367ca50efa4a>:4: ClusterWarning:
#
# scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix

# %% [markdown]
# # **Tanimoto**

# %%
#Matriz 1
fig = ff.create_dendrogram(distance_tani, labels= lab)
fig.update_layout(width=800, height=500,  title = "  T_Mentagrophytes (Tanimoto 1)", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f9b77ebd-d290-4846-a3d4-f697c8c1eeeb" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9b77ebd-d290-4846-a3d4-f697c8c1eeeb")) {                    Plotly.newPlot(                        "f9b77ebd-d290-4846-a3d4-f697c8c1eeeb",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[15.0,15.0,25.0,25.0],"xaxis":"x","y":[0.0,0.717385265155393,0.717385265155393,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[5.0,5.0,20.0,20.0],"xaxis":"x","y":[0.0,0.9025435445914131,0.9025435445914131,0.717385265155393],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[35.0,35.0,45.0,45.0],"xaxis":"x","y":[0.0,0.797683123467639,0.797683123467639,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[55.0,55.0,65.0,65.0],"xaxis":"x","y":[0.0,0.7567308190551773,0.7567308190551773,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[85.0,85.0,95.0,95.0],"xaxis":"x","y":[0.0,0.43360424680742116,0.43360424680742116,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[75.0,75.0,90.0,90.0],"xaxis":"x","y":[0.0,0.65937293680424,0.65937293680424,0.43360424680742116],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[105.0,105.0,115.0,115.0],"xaxis":"x","y":[0.0,0.7736100038281224,0.7736100038281224,0.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[82.5,82.5,110.0,110.0],"xaxis":"x","y":[0.65937293680424,0.8448082317943473,0.8448082317943473,0.7736100038281224],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[60.0,60.0,96.25,96.25],"xaxis":"x","y":[0.7567308190551773,1.0425344550354616,1.0425344550354616,0.8448082317943473],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[40.0,40.0,78.125,78.125],"xaxis":"x","y":[0.797683123467639,1.0687838501811553,1.0687838501811553,1.0425344550354616],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[12.5,12.5,59.0625,59.0625],"xaxis":"x","y":[0.9025435445914131,1.095907426000611,1.095907426000611,1.0687838501811553],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":500,"hovermode":"closest","showlegend":false,"width":800,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["11 (125/125)","13 (125/>250)","14 (62/250)","15 (250/>250)","16 (31/125)","7 (31/125)","10 (62/62)","8 (62/62)","6 (62/62)","12 (62/125)","9 (62/62)","17 (62/125)"],"tickvals":[5.0,15.0,25.0,35.0,45.0,55.0,65.0,75.0,85.0,95.0,105.0,115.0],"type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2 ...

# %%
#Matriz 2
plt.figure(figsize=(20,5))
plt.title(" T_Mentagrophytes (Tanimoto 2)")
d = shc.dendrogram(shc.linkage(distance_tani, method = "ward"), labels = lab)
