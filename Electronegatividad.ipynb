# %% [markdown]
# <a href="https://colab.research.google.com/github/jisusP/Articulo/blob/main/Electronegatividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy scipy xlrd plotly.figure_factor
import pandas as pd
import numpy as np
from scipy.spatial.distance import pdist, squareform
import plotly.figure_factory as ff

df = pd.read_excel('Electronegatividad_Fukui.xlsx', index_col=0)
dist_matrix = pdist(df, metric='euclidean')
sim_matrix = 1 / (1 + squareform(dist_matrix))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ERROR: Could not find a version that satisfies the requirement plotly.figure_factor (from versions: none)
# ERROR: No matching distribution found for plotly.figure_factor

# %% [markdown]
# Càndida

# %%
distance_matrix_Ea = 1- sim_matrix 
lab_Ca= ["6 (62/250)","7 (>250)","8 (>250)","9 (62/250)","10 (125/250)","11 (>250)","12 (>250)","13 (125/>250)","14 (250/>250)","15 (>250)", "16 (62/250)", "17(>250)"]
fig = ff.create_dendrogram(distance_matrix_Ea, labels=lab_Ca)
fig.update_layout(width=800, height=500, title = "Dendrograma", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
plt.figure(figsize=(18,5))
plt.title("Dendrograma 2")
d = shc.dendrogram(shc.linkage(distance_matrix_Ea, method = "ward"), labels = lab_Ca)
# Out:
# <ipython-input-3-52cebb00679e>:5: ClusterWarning:
#
# scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix

# %% [markdown]
# # **Sc**

# %%
lab_Sc= ["6 (62/250)","7 (>250)","8 (>250)","9 (62/250)","10 (62/125)","11 (>250)","12 (>250)","13 (250/>250)","14 (250/>250)","15 (>250)", "16 (62/250)", "17(125/250)"]
fig = ff.create_dendrogram(distance_matrix_Ea, labels=lab_Sc)
fig.update_layout(width=800, height=500, title = "Dendrograma", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Cn**

# %%
lab_Cn= ["6 (31/125)","7 (62/125)","8 (62/250)","9 (62/125)","10 (62/125)","11 (125/250)","12 (125/250)","13 (125/>250)","14 (125/250)","15 (>250)", "16 (62/125)", "17(125/250)"]
fig = ff.create_dendrogram(distance_matrix_Ea, labels=lab_Cn)
fig.update_layout(width=800, height=500, title = "Dendrograma", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Afl**

# %%
lab_Afl= ["6 (62/125)","7 (>250)","8 (125/250)","9 (62/125)","10 (62/125)","11 (>250)","12 (>250)","13 (250/>250)","14 (125/>250)","15 (250/>250)", "16 (125/250)", "17(250/>250)"]
fig = ff.create_dendrogram(distance_matrix_Ea, labels=lab_Afl)
fig.update_layout(width=800, height=500, title = "Dendrograma", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Afu**

# %%
lab_Afu= ["6 (62/125)","7 (>250)","8 (125/250)","9 (62/125)","10 (62/125)","11 (>250)","12 (>250)","13 (250/>250)","14 (125/>250)","15 (250/>250)", "16 (125/250)", "17(250/>250)"]
fig = ff.create_dendrogram(distance_matrix_Ea, labels=lab_Afu)
fig.update_layout(width=800, height=500, title = "Dendrograma", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Ani**

# %%
lab_Ani= ["6 (250/>250)","7 (>250)","8 (250/>250)","9 (62/125)","10 (125/250)","11 (>250)","12 (>250)","13 ( >250)","14 (125/>250)","15 (>250)", "16 (125/>250)", "17(250/>250)"]
fig = ff.create_dendrogram(distance_matrix_Ea, labels=lab_Ani)
fig.update_layout(width=800, height=500, title = "Dendrograma", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Mg**

# %%
lab_Mg= ["6 (62/62)","7 (31/125)","8 (62/62)","9 (62/62)","10 ( 62/62)","11 (125/125)","12 (31/62)","13 (125/>250)","14 (62/250)","15 (250/>250)", "16 (31/125)", "17(62/125)"]
fig = ff.create_dendrogram(distance_matrix_Ea, labels=lab_Mg)
fig.update_layout(width=800, height=500, title = "Dendrograma", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Tr**

# %%
lab_Tr= ["6 (62/62)","7 (31/125)","8 (62/62)","9 (62/62)","10 (62/62)","11 (125/125)","12 (31/62)","13 (125/>250)","14 (62/250)","15 (250/>250)", "16 (31/125)", "17(62/125)"]
fig = ff.create_dendrogram(distance_matrix_Ea, labels=lab_Tr)
fig.update_layout(width=800, height=500, title = "Dendrograma", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Tm**

# %%
lab_Tm= ["6 (62/62)","7 (31/125)","8 (62/62)","9 (62/62)","10 (62/62)","11 (125/125)","12 (62/125)","13 (125/>250)","14 (62/250)","15 (250/>250)", "16 (31/125)", "17(62/125)"]
fig = ff.create_dendrogram(distance_matrix_Ea, labels=lab_Tm)
fig.update_layout(width=800, height=500, title = "Dendrograma", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
